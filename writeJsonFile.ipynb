# %%
# Load the Drive helper and mount
from google.colab import drive, files
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import json
import os

# %%
# Work with JSON

emp = {
  "name": "John Smith",
  "age": 32,
  "email": "john.smith@example.com",
  "phone": "+44-7911-123456",
  "address": {
    "city": "London",
    "street_name": "Baker Street",
    "house_num": 221,
    "post_code": "NW1 6XE"
  }
}

# %%
record_str = json.dumps(emp)
record_str
# Out:
# '{"name": "John Smith", "age": 32, "email": "john.smith@example.com", "phone": "+44-7911-123456", "address": {"city": "London", "street_name": "Baker Street", "house_num": 221, "post_code": "NW1 6XE"}}'

# %%
type(record_str)
# Out:
# str

# %%
file_path = "C:\\Users\\aa_kh\\Downloads\\employee.json"
with open(file_path, "w") as f:
    json.dump(record_str, f, indent=4)

# Confirm file location
print("File saved at:", os.path.abspath(file_path))
# Out:
# File saved at: /content/C:\Users\aa_kh\Downloads\employee.json
